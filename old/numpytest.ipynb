# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def getIntersection(anchors):
    p1 = anchors[0]
    p2 = anchors[1]
    n1 = p1 - anchors[2]
    n2 = p2 - anchors[3]
    A = np.array([n1, n2]).T[:2]
    try:
        invA = np.linalg.inv(A)
    except:
        print("Lines do not intersect")
        return
    P = (p2 - p1)[:2]
    [S, T] = np.matmul(invA, P)
    print(T)
    print(S)
    print(p1 + S * n1)
    print(p2 - (T * n2))
    return p1 + S * n1

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(dist[0], dist[1], dist[2])
cross1 = np.array([anchors[0], anchors[2]]).T
cross2 = np.array([anchors[1], anchors[3]]).T
ax.plot(cross1[0], cross1[1], zs=cross1[2], c=[0, 0.8, 0])
ax.plot(cross2[0], cross1[2], zs=cross2[2], c=[0, 0.8, 0])
ax.scatter(highlight[0], highlight[1], highlight[2], c=[[0.9, 0, 0]])
# Out:
# (3, 2)

# %%
intersection = getIntersection(anchors)

# %%
ax.scatter(intersection[0], intersection[1], intersection[2], c=[[0, 0, 1]])
